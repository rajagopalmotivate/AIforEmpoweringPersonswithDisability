# %% [markdown]
# <a href="https://colab.research.google.com/github/rajagopalmotivate/AIforEmpoweringPersonswithDisability/blob/main/Lab_10_Web_Site_Creator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gemini API: System instructions

# %% [markdown]
# System instructions allow you to steer the behavior of the model. By setting the system instruction, you are giving the model additional context to understand the task, provide more customized responses, and adhere to guidelines over the user interaction. Product-level behavior can be specified here, separate from prompts provided by end users.
#
# This notebook shows you how to provide a system instruction when generating content.

# %%
# !pip install -U -q google-generativeai # Install the Python SDK

# %%
from google.colab import userdata
import google.generativeai as genai

# Secret can't be publicly displayed like this! But did it so that you can quickly try it out.. Please generate your own key
secretpassword =  "AIzaSyBwwlcMVpkxE0HyyNe5CDJ6O8-UvAmD6d0"

genai.configure(api_key= secretpassword )

# %% [markdown]
# ## Code generation

# %% [markdown]
# ## Set the system instruction 🐱

# %% [markdown]
# Below is an example of setting the system instruction when generating code.

# %%
instruction = (
    "You are a coding expert that specializes in front end interfaces. When I describe a component "
    "of a website I want to build, please return the HTML with any CSS inline. Embed javascript code in HTML to animate objects and make the website very interactive for generation X. Do not give an "
    "explanation for this code."
)

model = genai.GenerativeModel(
    "models/gemini-1.5-flash", system_instruction=instruction,
)

# %%
from google.generativeai import GenerationConfig
generation_config = GenerationConfig(temperature=0.99) # Set temperature value between 0.0 and 1.0

# %%
prompt = (
    "A professional website listing songs along with clickable tiles for each song, cool interactive expanding menu items with links, clickable tiles of music albumns with randomly populated images of different genres,  search button, randomly poulated recent social media feeds by music artistists. Populate with random images and titles"
)

# %%
response = model.generate_content(prompt, generation_config=generation_config)
print(response.text)
# Out:
# ```html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Music Mania</title>
# <style>
# body {
#   font-family: Arial, sans-serif;
#   background-color: #f4f4f4;
#   margin: 0;
#   padding: 0;
# }
#
# header {
#   background-color: #333;
#   color: #fff;
#   padding: 20px;
#   text-align: center;
# }
#
# nav {
#   background-color: #eee;
#   padding: 10px;
#   text-align: center;
# }
#
# nav a {
#   color: #333;
#   text-decoration: none;
#   margin: 0 10px;
# }
#
# main {
#   padding: 20px;
# }
#
# .song-list {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
#   gap: 20px;
# }
#
# .song-item {
#   border: 1px solid #ddd;
#   padding: 10px;
#   text-align: center;
#   position: relative;
#   overflow: hidden;
# }
#
# .song-item img {
#   width: 100%;
#   height: 150px;
#   object-fit: cover;
#   transition: transform 0.3s ease;
# }
#
# .song-item:hover img {
#   transform: scale(1.1);
# }
#
# .song-title {
#   font-weight: bold;
#   margin-top: 10px;
# ...

# %%
from IPython.display import HTML

# %%
response = model.generate_content(prompt, generation_config=generation_config)


# Render the HTML
HTML(response.text.strip().removeprefix("```html").removesuffix("```"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Music Paradise</title>
#     <style>
#         body {
#             font-family: sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #f0f0f0;
#         }
#
#         header {
#             background-color: #333;
#             color: #fff;
#             padding: 1rem 0;
#             text-align: center;
#         }
#
#         nav {
#             background-color: #222;
#             color: #fff;
#             padding: 1rem 0;
#             display: flex;
#             justify-content: space-around;
#             align-items: center;
#             position: fixed;
#             top: 0;
#             left: 0;
#             width: 100%;
#             z-index: 10;
#         }
#
#         nav ul {
#             list-style: none;
#             margin: 0;
#             padding: 0;
# ...
